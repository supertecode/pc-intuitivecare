# %%
import pdfplumber
import pandas as pd
import zipfile

# %%
# Nome do arquivo PDF (Anexo I)
pdf_file = "Anexo_I.pdf"

# Lista para armazenar os dados
data = []

# %%
# Abre o PDF
with pdfplumber.open(pdf_file) as pdf:
    for page in pdf.pages:
        tables = page.extract_table()  # Tenta extrair tabela da página
        if tables:
            data.extend(tables)  # Adiciona os dados extraídos à lista

# %%
# Converte os dados para um DataFrame
df = pd.DataFrame(data)
df.columns = df.iloc[0]  # Define a primeira linha como cabeçalho
df = df[1:].reset_index(drop=True)  # Remove a primeira linha antiga e reseta o índice

# %%
# Exibe as primeiras linhas
df.head(40)
# Out:
# 0                                        PROCEDIMENTO  RN\n(alteração)  \
# 0                             ACONSELHAMENTO GENÉTICO
# 1   ATENDIMENTO/ACOMPANHAMENTO EM HOSPITAL-DIA PSI...
# 2   ATENDIMENTO INTEGRAL AO RECÉM-NASCIDO (SALA DE...
# 3   ATENDIMENTO MÉDICO DO INTENSIVISTA EM UTI GERA...
# 4   ATENDIMENTO PEDIÁTRICO A GESTANTES (3º TRIMESTRE)
# 5    ATIVIDADE EDUCACIONAL PARA PLANEJAMENTO FAMILIAR
# 6                  ATIVIDADE EDUCATIVA EM SAÚDE BUCAL
# 7   ATIVIDADE EDUCATIVA EM ODONTOLOGIA PARA PAIS E...
# 8   CONDICIONAMENTO EM ODONTOLOGIA (COM DIRETRIZ D...
# 9   ESTABILIZAÇÃO DE PACIENTE POR MEIO DE CONTENÇÃ...
# 10  CONSULTA DE ACONSELHAMENTO PARA PLANEJAMENTO F...
# 11  CONSULTA COM ENFERMEIRO OBSTETRA OU OBSTETRIZ ...
# 12              CONSULTA/AVALIAÇÃO COM FISIOTERAPEUTA         541/2022
# 13                                    CONSULTA MÉDICA
# 14                              CONSULTA ODONTOLÓGICA
# 15                      CONSULTA ODONTOLÓGICA INICIAL
# 16                  CONSULTA ODONTOLÓGICA DE URGÊNCIA
# 17  CONSULTA ODONTOLÓGICA PARA AVALIAÇÃO TÉCNICA D...
# 18                   CONSULTA/AVALIAÇÃO COM PSICÓLOGO         541/2022
# 19                                       PROCEDIMENTO  RN\n(alteração)
# 20                               SESSÃO COM PSICÓLOGO         541/2022
# 21               CONSULTA/AVALIAÇÃO COM FONOAUDIÓLOGO         541/2022
# 22                           SESSÃO COM FONOAUDIÓLOGO         541/2022
# 23  CONSULTA COM NUTRICIONISTA (COM DIRETRIZ DE UT...
# 24       CONSULTA/AVALIAÇÃO COM TERAPEUTA OCUPACIONAL         541/2022
# 25                   SESSÃO COM TERAPEUTA OCUPACIONAL         541/2022
# 26  TRANSPORTE EXTRA-HOSPITALAR DE PACIENTES GRAVE...
# 27                                  VISITA HOSPITALAR
# 28  ACOMPANHAMENTO CLÍNICO AMBULATORIAL PÓS-TRANSP...
# 29  ACOMPANHAMENTO CLÍNICO AMBULATORIAL PÓS-TRANSP...
# 30  ACOMPANHAMENTO CLÍNICO AMBULATORIAL PÓS-TRANSP...         546/2022
# 31  ACOMPANHAMENTO CLÍNICO AMBULATORIAL PÓS-TRANSP...
# 32  ACOMPANHAMENTO CLÍNICO DE TRANSPLANTE HEPÁTICO...         546/2022
# 33  ACOMPANHAMENTO CLÍNICO DE TRANSPLANTE RENAL NO...
# 34   AVALIAÇÃO CLÍNICA DIARIA ENTERAL E/OU PARENTERAL
# 35  AVALIAÇÃO CLÍNICA E ELETRÔNICA DE PACIENTE POR...
# 36        CARDIOVERSÃO ELÉTRICA COM ELETROCARDIOGRAMA
# 37     CONTROLE DE BIOFILME DENTAL (PLACA BACTERIANA)
# 38  FORNECIMENTO DE EQUIPAMENTOS COLETORES E ADJUV...
# 39                                       PROCEDIMENTO  RN\n(alteração)
#
# 0     VIGÊNCIA  OD  AMB  HCO  HSO  REF  PAC  DUT  \
# 0                   AMB  HCO  HSO  REF
# 1                        HCO  HSO  REF       109
# 2                        HCO       REF
# 3                        HCO  HSO  REF
# 4                   AMB  HCO       REF
# 5                   AMB            REF
# 6               OD
# 7               OD
# 8               OD                            86
# 9               OD
# 10                  AMB            REF
# 11                  AMB  HCO       REF       135
# 12  01/08/2022      AMB            REF
# 13                  AMB            REF
# 14              OD
# 15              OD
# 16              OD
# 17              OD
# 18  01/08/2022      AMB            REF
# 19    VIGÊNCIA  OD  AMB  HCO  HSO  REF  PAC  DUT
# 20  01/08/2022      AMB            REF
# 21  01/08/2022      AMB            REF
# 22  01/08/2022      AMB            REF
# 23                  AMB            REF       103
# 24  01/08/2022      AMB            REF
# 25  01/08/2022      AMB            REF
# 26                       HCO  HSO  REF
# 27                       HCO  HSO  REF
# 28                       HCO  HSO  REF
# 29                       HCO  HSO  REF
# 30  03/10/2022           HCO  HSO  REF
# 31                       HCO  HSO  REF
# 32  03/10/2022           HCO  HSO  REF  PAC
# 33                       HCO  HSO  REF  PAC
# 34                       HCO  HSO  REF
# 35                  AMB  HCO  HSO  REF
# 36                  AMB  HCO  HSO  REF
# 37              OD
# 38                  AMB  HCO  HSO  REF
# 39    VIGÊNCIA  OD  AMB  HCO  HSO  REF  PAC  DUT
#
# 0                                            SUBGRUPO  \
# 0   CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 1   CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 2   CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 3   CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 4   CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 5   CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 6   CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 7   CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 8   CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 9   CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 10  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 11  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 12  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 13  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 14  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 15  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 16  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 17  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 18  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 19                                           SUBGRUPO
# 20  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 21  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 22  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 23  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 24  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 25  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 26  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 27  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...
# 28                         AVALIAÇÕES/ACOMPANHAMENTOS
# 29                         AVALIAÇÕES/ACOMPANHAMENTOS
# 30                         AVALIAÇÕES/ACOMPANHAMENTOS
# 31                         AVALIAÇÕES/ACOMPANHAMENTOS
# 32                         AVALIAÇÕES/ACOMPANHAMENTOS
# 33                         AVALIAÇÕES/ACOMPANHAMENTOS
# 34                         AVALIAÇÕES/ACOMPANHAMENTOS
# 35                         AVALIAÇÕES/ACOMPANHAMENTOS
# 36                         AVALIAÇÕES/ACOMPANHAMENTOS
# 37                         AVALIAÇÕES/ACOMPANHAMENTOS
# 38                         AVALIAÇÕES/ACOMPANHAMENTOS
# 39                                           SUBGRUPO
#
# 0                                               GRUPO  \
# 0                                PROCEDIMENTOS GERAIS
# 1                                PROCEDIMENTOS GERAIS
# 2                                PROCEDIMENTOS GERAIS
# 3                                PROCEDIMENTOS GERAIS
# 4                                PROCEDIMENTOS GERAIS
# 5                                PROCEDIMENTOS GERAIS
# 6                                PROCEDIMENTOS GERAIS
# 7                                PROCEDIMENTOS GERAIS
# 8                                PROCEDIMENTOS GERAIS
# 9                                PROCEDIMENTOS GERAIS
# 10                               PROCEDIMENTOS GERAIS
# 11                               PROCEDIMENTOS GERAIS
# 12                               PROCEDIMENTOS GERAIS
# 13                               PROCEDIMENTOS GERAIS
# 14                               PROCEDIMENTOS GERAIS
# 15                               PROCEDIMENTOS GERAIS
# 16                               PROCEDIMENTOS GERAIS
# 17                               PROCEDIMENTOS GERAIS
# 18                               PROCEDIMENTOS GERAIS
# 19                                              GRUPO
# 20                               PROCEDIMENTOS GERAIS
# 21                               PROCEDIMENTOS GERAIS
# 22                               PROCEDIMENTOS GERAIS
# 23                               PROCEDIMENTOS GERAIS
# 24                               PROCEDIMENTOS GERAIS
# 25                               PROCEDIMENTOS GERAIS
# 26                               PROCEDIMENTOS GERAIS
# 27                               PROCEDIMENTOS GERAIS
# 28  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 29  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 30  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 31  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 32  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 33  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 34  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 35  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 36  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 37  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 38  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 39                                              GRUPO
#
# 0                                            CAPÍTULO
# 0                                PROCEDIMENTOS GERAIS
# 1                                PROCEDIMENTOS GERAIS
# 2                                PROCEDIMENTOS GERAIS
# 3                                PROCEDIMENTOS GERAIS
# 4                                PROCEDIMENTOS GERAIS
# 5                                PROCEDIMENTOS GERAIS
# 6                                PROCEDIMENTOS GERAIS
# 7                                PROCEDIMENTOS GERAIS
# 8                                PROCEDIMENTOS GERAIS
# 9                                PROCEDIMENTOS GERAIS
# 10                               PROCEDIMENTOS GERAIS
# 11                               PROCEDIMENTOS GERAIS
# 12                               PROCEDIMENTOS GERAIS
# 13                               PROCEDIMENTOS GERAIS
# 14                               PROCEDIMENTOS GERAIS
# 15                               PROCEDIMENTOS GERAIS
# 16                               PROCEDIMENTOS GERAIS
# 17                               PROCEDIMENTOS GERAIS
# 18                               PROCEDIMENTOS GERAIS
# 19                                           CAPÍTULO
# 20                               PROCEDIMENTOS GERAIS
# 21                               PROCEDIMENTOS GERAIS
# 22                               PROCEDIMENTOS GERAIS
# 23                               PROCEDIMENTOS GERAIS
# 24                               PROCEDIMENTOS GERAIS
# 25                               PROCEDIMENTOS GERAIS
# 26                               PROCEDIMENTOS GERAIS
# 27                               PROCEDIMENTOS GERAIS
# 28  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 29  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 30  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 31  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 32  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 33  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 34  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 35  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 36  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 37  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 38  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS\nE HOSPIT...
# 39                                           CAPÍTULO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3570 entries, 0 to 3569
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROCEDIMENTO    3570 non-null   object
#  1   RN
# (alteração)  3570 non-null   object
#  2   VIGÊNCIA        3570 non-null   object
#  3   OD              3570 non-null   object
#  4   AMB             3570 non-null   object
#  5   HCO             3570 non-null   object
#  6   HSO             3570 non-null   object
#  7   REF             3570 non-null   object
#  8   PAC             3570 non-null   object
#  9   DUT             3570 non-null   object
#  10  SUBGRUPO        3570 non-null   object
#  11  GRUPO           3570 non-null   object
#  12  CAPÍTULO        3570 non-null   object
# dtypes: object(13)
# memory usage: 362.7+ KB

# %%
print(df.columns)
# Out:
# Index(['PROCEDIMENTO', 'RN\n(alteração)', 'VIGÊNCIA', 'OD', 'AMB', 'HCO',
#        'HSO', 'REF', 'PAC', 'DUT', 'SUBGRUPO', 'GRUPO', 'CAPÍTULO'],
#       dtype='object', name=0)

# %%
# Dicionário de substituição (ajuste conforme legenda do PDF)
df = df.rename(columns={'OD': 'Seg. Odontológica'})
df = df.rename(columns={'AMB': 'Seg. Ambulatorial'})

# %%
df.head()
# Out:
# 0                                       PROCEDIMENTO RN\n(alteração) VIGÊNCIA  \
# 0                            ACONSELHAMENTO GENÉTICO
# 1  ATENDIMENTO/ACOMPANHAMENTO EM HOSPITAL-DIA PSI...
# 2  ATENDIMENTO INTEGRAL AO RECÉM-NASCIDO (SALA DE...
# 3  ATENDIMENTO MÉDICO DO INTENSIVISTA EM UTI GERA...
# 4  ATENDIMENTO PEDIÁTRICO A GESTANTES (3º TRIMESTRE)
#
# 0 Seg. Odontológica Seg. Ambulatorial  HCO  HSO  REF PAC  DUT  \
# 0                        Ambulatorial  HCO  HSO  REF
# 1                                      HCO  HSO  REF      109
# 2                                      HCO       REF
# 3                                      HCO  HSO  REF
# 4                        Ambulatorial  HCO       REF
#
# 0                                           SUBGRUPO                 GRUPO  \
# 0  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...  PROCEDIMENTOS GERAIS
# 1  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...  PROCEDIMENTOS GERAIS
# 2  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...  PROCEDIMENTOS GERAIS
# 3  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...  PROCEDIMENTOS GERAIS
# 4  CONSULTAS, VISITAS HOSPITALARES OU\nACOMPANHAM...  PROCEDIMENTOS GERAIS
#
# 0              CAPÍTULO
# 0  PROCEDIMENTOS GERAIS
# 1  PROCEDIMENTOS GERAIS
# 2  PROCEDIMENTOS GERAIS
# 3  PROCEDIMENTOS GERAIS
# 4  PROCEDIMENTOS GERAIS

# %%
# Salva em CSV
csv_file = "Rol_de_Procedimentos.csv"
df.to_csv(csv_file, index=False, encoding="utf-8")

print(f"Arquivo {csv_file} salvo com sucesso!")
# Out:
# Arquivo Rol_de_Procedimentos.csv salvo com sucesso!

# %%
# Nome do ZIP final
zip_name = "Teste_Murilo.zip"

# Compacta o CSV
with zipfile.ZipFile(zip_name, "w") as zipf:
    zipf.write(csv_file)
    print(f"{csv_file} adicionado ao {zip_name}")

print(f"Arquivo {zip_name} criado com sucesso!")
# Out:
# Rol_de_Procedimentos.csv adicionado ao Teste_Murilo.zip
# Arquivo Teste_Murilo.zip criado com sucesso!
